# %% [markdown]
# # Análisis de la telemetría de Timeless Deck
#
# Limpiamos los valores y los ordenamos por su timestamp.

# %%
from loader import Loader
import numpy as np
import pandas as pd
# Carga de archivos

loader = Loader("telemetry.json", False)

dataSorted = loader.data

dataSorted = dataSorted.sort_values("timestamp")
# Display all rows of the DataFrame
pd.set_option("display.max_rows", None)
display(dataSorted)
# Out:
#       id     eventType               timestamp  levelId           x  \
# 62     0    GAME:START 2024-04-16 10:10:12.854      NaN         NaN
# 78     1   LEVEL:START 2024-04-16 10:10:12.915      1.0         NaN
# 120    2  PLAYER:DEATH 2024-04-16 10:10:17.055      NaN  254.928932
# 40     3  PLAYER:DEATH 2024-04-16 10:10:26.171      NaN  310.897825
# 26     4     LEVEL:END 2024-04-16 10:10:29.688      1.0         NaN
# 11     5   LEVEL:START 2024-04-16 10:10:29.721      2.0         NaN
# 90     6  PLAYER:DEATH 2024-04-16 10:10:33.939      NaN  497.759740
# 122    7  PLAYER:DEATH 2024-04-16 10:10:44.172      NaN  502.169300
# 108    8  PLAYER:DEATH 2024-04-16 10:10:47.121      NaN  578.136401
# 91     9     LEVEL:END 2024-04-16 10:10:54.455      2.0         NaN
# 112   10   LEVEL:START 2024-04-16 10:10:54.493      3.0         NaN
# 124   11  PLAYER:DEATH 2024-04-16 10:10:59.705      NaN  664.426407
# 80    12  PLAYER:DEATH 2024-04-16 10:11:02.972      NaN  551.023689
# 93    13  PLAYER:DEATH 2024-04-16 10:11:09.906      NaN  457.257215
# 28    14  PLAYER:DEATH 2024-04-16 10:11:14.072      NaN  716.714045
# 59    15  PLAYER:DEATH 2024-04-16 10:11:15.455      NaN  432.000000
# 12    16  PLAYER:DEATH 2024-04-16 10:11:18.189      NaN  320.619288
# 27    17     LEVEL:END 2024-04-16 10:11:28.705      3.0         NaN
# 94    18   LEVEL:START 2024-04-16 10:11:28.732      4.0         NaN
# 113   19  PLAYER:DEATH 2024-04-16 10:11:37.256      NaN  434.323533
# 65    20  PLAYER:DEATH 2024-04-16 10:11:40.039      NaN  318.927117
# 47    21  PLAYER:DEATH 2024-04-16 10:11:43.089      NaN  199.406085
# 30    22  PLAYER:DEATH 2024-04-16 10:11:44.139      NaN  432.000000
# 15    23  PLAYER:DEATH 2024-04-16 10:11:46.439      NaN  425.333333
# 128   24  PLAYER:DEATH 2024-04-16 10:11:48.589      NaN  333.952621
# 115   25  PLAYER:DEATH 2024-04-16 10:11:50.622      NaN  353.715729
# 98    26  PLAYER:DEATH 2024-04-16 10:12:04.474      NaN  200.522164
# 85    27  PLAYER:DEATH 2024-04-16 10:12:05.539      NaN  428.666667
# 49    28  PLAYER:DEATH 2024-04-16 10:12:07.856      NaN  428.666667
# 31    29  PLAYER:DEATH 2024-04-16 10:12:13.140      NaN  303.785113
# 52    30  PLAYER:DEATH 2024-04-16 10:12:17.757      NaN  480.521164
# 34    31  PLAYER:DEATH 2024-04-16 10:12:21.407      NaN  467.732000
# 183   46    GAME:START 2024-04-16 10:35:29.718      NaN         NaN
# 176   47   LEVEL:START 2024-04-16 10:35:29.744      1.0         NaN
# 175   48     LEVEL:END 2024-04-16 10:35:42.801      1.0         NaN
# 169   49   LEVEL:START 2024-04-16 10:35:42.828      2.0         NaN
# 158   50     LEVEL:END 2024-04-16 10:35:58.434      2.0         NaN
# 149   51   LEVEL:START 2024-04-16 10:35:58.469      3.0         NaN
# 140   52  PLAYER:DEATH 2024-04-16 10:36:10.985      NaN  137.197372
# 207   53  PLAYER:DEATH 2024-04-16 10:36:14.268      NaN  307.546405
# 202   54  PLAYER:DEATH 2024-04-16 10:36:17.485      NaN  388.702860
# 192   55  PLAYER:DEATH 2024-04-16 10:36:19.452      NaN  468.903559
# 184   56  PLAYER:DEATH 2024-04-16 10:36:24.136      NaN  762.000000
# 177   57  PLAYER:DEATH 2024-04-16 10:36:26.552      NaN  672.710678
# 150   58  PLAYER:DEATH 2024-04-16 10:36:28.102      NaN  432.000000
# 141   59     LEVEL:END 2024-04-16 10:36:32.868      3.0         NaN
# 163   60   LEVEL:START 2024-04-16 10:36:32.898      4.0         NaN
# 144   61  PLAYER:DEATH 2024-04-16 10:36:45.469      NaN  388.592100
# 161   62  PLAYER:DEATH 2024-04-16 10:36:47.235      NaN  457.927249
# 194   63  PLAYER:DEATH 2024-04-16 10:36:52.501      NaN  518.331650
# 145   64  PLAYER:DEATH 2024-04-16 10:37:08.819      NaN  294.854366
# 182   65  PLAYER:DEATH 2024-04-16 10:37:12.002      NaN  433.878055
# 164   66  PLAYER:DEATH 2024-04-16 10:37:14.685      NaN  229.001684
# 200   67  PLAYER:DEATH 2024-04-16 10:37:19.486      NaN  244.455147
# 157   68  PLAYER:DEATH 2024-04-16 10:37:22.169      NaN  342.832360
# 196   69     LEVEL:END 2024-04-16 10:37:27.852      4.0         NaN
# 162   70      GAME:END 2024-04-16 10:37:29.519      NaN         NaN
#
#               y result
# 62          NaN    NaN
# 78          NaN    NaN
# 120  630.404401    NaN
# 40   444.719946    NaN
# 26          NaN   PASS
# 11          NaN    NaN
# 90   528.047379    NaN
# 122  441.686500    NaN
# 108  527.258091    NaN
# 91          NaN   PASS
# 112         NaN    NaN
# 124  528.856181    NaN
# 80   532.357023    NaN
# 93   413.835859    NaN
# 28   438.047379    NaN
# 59   400.000000    NaN
# 12   335.285955    NaN
# 27          NaN   PASS
# 94          NaN    NaN
# 113  345.993586    NaN
# 65   331.820667    NaN
# 47   347.406085    NaN
# 30   400.000000    NaN
# 15   496.666667    NaN
# 128  438.047379    NaN
# 115  435.049062    NaN
# 98   334.839871    NaN
# 85   400.000000    NaN
# 49   526.666667    NaN
# 31   531.785113    NaN
# 52   639.468735    NaN
# 34   554.442670    NaN
# 19   554.442670    NaN
# 3           NaN   FAIL
# 131         NaN   FAIL
# 118         NaN    NaN
# 101         NaN    NaN
# 87          NaN   PASS
# 68          NaN    NaN
# 51   430.150919    NaN
# 54   337.238576    NaN
# 36          NaN   PASS
# 21          NaN    NaN
# 7    337.238576    NaN
# 119  553.231333    NaN
# 105  341.143819    NaN
# 88   602.022006    NaN
# 71   434.309644    NaN
# 70   331.820667    NaN
# 53   349.136681    NaN
# 38          NaN   PASS
# 24          NaN    NaN
# 9    498.925565    NaN
# 134  446.499158    NaN
# 5    631.098574    NaN
# 106  437.663064    NaN
# 89   436.094757    NaN
# 74   636.119429    NaN
# 25   445.118446    NaN
# 10   334.644661    NaN
# 57   367.987387    NaN
# 77   444.714045    NaN
# 92   525.355339    NaN
# 110  525.355339    NaN
# 136         NaN   FAIL
# 64          NaN   FAIL
# 35          NaN    NaN
# 8           NaN    NaN
# 42          NaN   PASS
# 58          NaN    NaN
# 44   531.004656    NaN
# 60          NaN   PASS
# 81          NaN    NaN
# 95   349.595599    NaN
# 114  540.876028    NaN
# 125  345.942282    NaN
# 137         NaN   PASS
# 13          NaN    NaN
# 29   432.887954    NaN
# 45   411.006408    NaN
# 130  542.593915    NaN
# 2    472.582947    NaN
# 18   427.219322    NaN
# 32   400.000000    NaN
# 73   446.688316    NaN
# 109  428.047379    NaN
# 99          NaN   PASS
# 116         NaN   PASS
# 1           NaN    NaN
# 16          NaN    NaN
# 46   530.671527    NaN
# 48          NaN   PASS
# 66          NaN    NaN
# 86   529.428090    NaN
# 82   351.213203    NaN
# 127  344.477153    NaN
# 129  583.368147    NaN
# 135         NaN   PASS
# 69          NaN    NaN
# 104  436.656334    NaN
# 117  426.011667    NaN
# 43   403.096441    NaN
# 84   337.977994    NaN
# 100         NaN   PASS
# 41          NaN    NaN
# 67   440.537339    NaN
# 17   629.394214    NaN
# 72   596.666667    NaN
# 102  347.238576    NaN
# 97          NaN   PASS
# 79          NaN   PASS
# 33          NaN    NaN
# 0           NaN    NaN
# 126         NaN   PASS
# 39          NaN    NaN
# 103  523.799787    NaN
# 4           NaN   PASS
# 14          NaN    NaN
# 96   426.011667    NaN
# 123  436.094757    NaN
# 50   593.639610    NaN
# 22          NaN   PASS
# 111         NaN    NaN
# 83   439.826729    NaN
# 20   432.357023    NaN
# 133  437.071068    NaN
# 63   365.238472    NaN
# 132  437.071068    NaN
# 56   434.038196    NaN
# 76   501.340379    NaN
# 55   536.331650    NaN
# 75   339.693723    NaN
# 23   330.833607    NaN
# 37   356.834175    NaN
# 121  352.153726    NaN
# 6    486.666667    NaN
# 107         NaN   FAIL
# 61          NaN   FAIL
# 186         NaN    NaN
# 178         NaN    NaN
# 171  531.785113    NaN
# 159         NaN   PASS
# 151         NaN    NaN
# 142  628.656057    NaN
# 208  440.760022    NaN
# 203         NaN   PASS
# 193         NaN    NaN
# 199  628.758057    NaN
# 195  335.216571    NaN
# 204         NaN   PASS
# 179         NaN    NaN
# 187  438.817795    NaN
# 160  430.000000    NaN
# 172  449.497475    NaN
# 143  435.118446    NaN
# 152  355.312892    NaN
# 188  335.441870    NaN
# 185  434.911159    NaN
# 173  427.326667    NaN
# 165  445.619366    NaN
# 153  414.309644    NaN
# 146  439.023689    NaN
# 205  432.998316    NaN
# 197         NaN   PASS
# 189         NaN   PASS
# 180         NaN    NaN
# 166         NaN    NaN
# 154         NaN   PASS
# 168         NaN    NaN
# 155  332.356983    NaN
# 147  400.000000    NaN
# 138         NaN   PASS
# 206         NaN    NaN
# 198  433.986351    NaN
# 190  550.962727    NaN
# 181  620.727667    NaN
# 174         NaN   PASS
# 167         NaN    NaN
# 170  617.394333    NaN
# 156  446.499158    NaN
# 148  523.974627    NaN
# 139  359.792383    NaN
# 201         NaN   PASS
# 191         NaN   PASS
# 183         NaN    NaN
# 176         NaN    NaN
# 175         NaN   PASS
# 169         NaN    NaN
# 158         NaN   PASS
# 149         NaN    NaN
# 140  626.053492    NaN
# 207  620.727667    NaN
# 202  570.895175    NaN
# 192  450.571910    NaN
# 184  443.333333    NaN
# 177  442.884220    NaN
# 150  400.000000    NaN
# 141         NaN   PASS
# 163         NaN    NaN
# 144  615.320831    NaN
# 161  340.739418    NaN
# 194  343.668350    NaN
# 145  453.381830    NaN
# 182  541.287794    NaN
# 164  347.001684    NaN
# 200  620.727667    NaN
# 157  659.407905    NaN
# 196         NaN   PASS
# 162         NaN   PASS

# %% [markdown]
# # Preguntas a responder
# + Determinar si la interfaz de la escena de combate transmite las mecánicas del juego.
#   + ¿El jugador entiende el funcionamiento de las cartas?
#   + ¿El jugador entiende las tres barras superiores?
#   + ¿El jugador entiende qué tiene que hacer para salir del nivel, y cuándo lo puede hacer?
#
# + Determinar el grado de comprensión del inventario.
#   + ¿Entiende el jugador cómo gestionar sus cartas?

# %% [markdown]
# ## ¿El jugador entiende el funcionamiento de las cartas?
#
# + Cambio de carta voluntario.
#   + Promedio de número de habilidades usadas por nivel.
# + Uso de habilidad.
#   + Promedio de habilidades usadas con éxito (ha hecho algo de daño o ha curado), por nivel.

# %%
# Coger todos los eventos de habilidades usadas y de disparos??
game_start_events = dataSorted[dataSorted["eventType"] == "GAME:START"]
game_end_events = dataSorted[dataSorted["eventType"] == "GAME:END"]

# ejemplo loop

start_timestamp_series = game_start_events.head(n=1)["timestamp"]
end_timestamp = game_end_events.head(n=1)["timestamp"]



display(type(start_timestamp_series))
display(end_timestamp)

death_events = dataSorted[dataSorted["eventType"] == "PLAYER:DEATH"]
death_events = death_events[death_events["timestamp"] >= start_timestamp.values[0]]
death_events = death_events[death_events["timestamp"] <= end_timestamp.values[0]]


test_events = dataSorted[dataSorted["timestamp"] >= start_timestamp.values[0]]
test_events = test_events[test_events["timestamp"] <= end_timestamp.values[0]]


display(game_start_events)
display(game_end_events)
display(death_events)
display(test_events)
display(test_events.count())
display(death_events.count())
# Separarlos por nivel
# Sacar la media
# Out:
# pandas.core.series.Series
# 131   2024-04-16 10:12:26.174
# Name: timestamp, dtype: datetime64[ns]
#       id   eventType               timestamp  levelId   x   y result
# 62     0  GAME:START 2024-04-16 10:10:12.854      NaN NaN NaN    NaN
# 118   35  GAME:START 2024-04-16 10:13:07.442      NaN NaN NaN    NaN
# 35    66  GAME:START 2024-04-16 10:15:19.493      NaN NaN NaN    NaN
# 1     88  GAME:START 2024-04-16 10:17:00.945      NaN NaN NaN    NaN
# 33   111  GAME:START 2024-04-16 10:18:59.231      NaN NaN NaN    NaN
# 186    0  GAME:START 2024-04-16 10:31:51.816      NaN NaN NaN    NaN
# 180   27  GAME:START 2024-04-16 10:33:50.650      NaN NaN NaN    NaN
# 183   46  GAME:START 2024-04-16 10:35:29.718      NaN NaN NaN    NaN
#       id eventType               timestamp  levelId   x   y result
# 131   34  GAME:END 2024-04-16 10:12:26.174      NaN NaN NaN   FAIL
# 64    65  GAME:END 2024-04-16 10:15:14.842      NaN NaN NaN   FAIL
# 116   87  GAME:END 2024-04-16 10:16:59.346      NaN NaN NaN   PASS
# 79   110  GAME:END 2024-04-16 10:18:55.364      NaN NaN NaN   PASS
# 61   137  GAME:END 2024-04-16 10:21:00.199      NaN NaN NaN   FAIL
# 189   26  GAME:END 2024-04-16 10:33:46.634      NaN NaN NaN   PASS
# 191   45  GAME:END 2024-04-16 10:35:26.667      NaN NaN NaN   PASS
# 162   70  GAME:END 2024-04-16 10:37:29.519      NaN NaN NaN   PASS
#      id     eventType               timestamp  levelId           x  \
# 120   2  PLAYER:DEATH 2024-04-16 10:10:17.055      NaN  254.928932
# 40    3  PLAYER:DEATH 2024-04-16 10:10:26.171      NaN  310.897825
# 90    6  PLAYER:DEATH 2024-04-16 10:10:33.939      NaN  497.759740
# 122   7  PLAYER:DEATH 2024-04-16 10:10:44.172      NaN  502.169300
# 108   8  PLAYER:DEATH 2024-04-16 10:10:47.121      NaN  578.136401
# 124  11  PLAYER:DEATH 2024-04-16 10:10:59.705      NaN  664.426407
# 80   12  PLAYER:DEATH 2024-04-16 10:11:02.972      NaN  551.023689
# 93   13  PLAYER:DEATH 2024-04-16 10:11:09.906      NaN  457.257215
# 28   14  PLAYER:DEATH 2024-04-16 10:11:14.072      NaN  716.714045
# 59   15  PLAYER:DEATH 2024-04-16 10:11:15.455      NaN  432.000000
# 12   16  PLAYER:DEATH 2024-04-16 10:11:18.189      NaN  320.619288
# 113  19  PLAYER:DEATH 2024-04-16 10:11:37.256      NaN  434.323533
# 65   20  PLAYER:DEATH 2024-04-16 10:11:40.039      NaN  318.927117
# 47   21  PLAYER:DEATH 2024-04-16 10:11:43.089      NaN  199.406085
# 30   22  PLAYER:DEATH 2024-04-16 10:11:44.139      NaN  432.000000
# 15   23  PLAYER:DEATH 2024-04-16 10:11:46.439      NaN  425.333333
# 128  24  PLAYER:DEATH 2024-04-16 10:11:48.589      NaN  333.952621
# 115  25  PLAYER:DEATH 2024-04-16 10:11:50.622      NaN  353.715729
# 98   26  PLAYER:DEATH 2024-04-16 10:12:04.474      NaN  200.522164
# 85   27  PLAYER:DEATH 2024-04-16 10:12:05.539      NaN  428.666667
# 49   28  PLAYER:DEATH 2024-04-16 10:12:07.856      NaN  428.666667
# 31   29  PLAYER:DEATH 2024-04-16 10:12:13.140      NaN  303.785113
# 52   30  PLAYER:DEATH 2024-04-16 10:12:17.757      NaN  480.521164
# 34   31  PLAYER:DEATH 2024-04-16 10:12:21.407      NaN  467.732000
# 19   32  PLAYER:DEATH 2024-04-16 10:12:22.208      NaN  467.732000
#
#               y result
# 120  630.404401    NaN
# 40   444.719946    NaN
# 90   528.047379    NaN
# 122  441.686500    NaN
# 108  527.258091    NaN
# 124  528.856181    NaN
# 80   532.357023    NaN
# 93   413.835859    NaN
# 28   438.047379    NaN
# 59   400.000000    NaN
# 12   335.285955    NaN
# 113  345.993586    NaN
# 65   331.820667    NaN
# 47   347.406085    NaN
# 30   400.000000    NaN
# 15   496.666667    NaN
# 128  438.047379    NaN
# 115  435.049062    NaN
# 98   334.839871    NaN
# 85   400.000000    NaN
# 49   526.666667    NaN
# 31   531.785113    NaN
# 52   639.468735    NaN
# 34   554.442670    NaN
# 19   554.442670    NaN
#      id     eventType               timestamp  levelId           x  \
# 62    0    GAME:START 2024-04-16 10:10:12.854      NaN         NaN
# 78    1   LEVEL:START 2024-04-16 10:10:12.915      1.0         NaN
# 120   2  PLAYER:DEATH 2024-04-16 10:10:17.055      NaN  254.928932
# 40    3  PLAYER:DEATH 2024-04-16 10:10:26.171      NaN  310.897825
# 26    4     LEVEL:END 2024-04-16 10:10:29.688      1.0         NaN
# 11    5   LEVEL:START 2024-04-16 10:10:29.721      2.0         NaN
# 90    6  PLAYER:DEATH 2024-04-16 10:10:33.939      NaN  497.759740
# 122   7  PLAYER:DEATH 2024-04-16 10:10:44.172      NaN  502.169300
# 108   8  PLAYER:DEATH 2024-04-16 10:10:47.121      NaN  578.136401
# 91    9     LEVEL:END 2024-04-16 10:10:54.455      2.0         NaN
# 112  10   LEVEL:START 2024-04-16 10:10:54.493      3.0         NaN
# 124  11  PLAYER:DEATH 2024-04-16 10:10:59.705      NaN  664.426407
# 80   12  PLAYER:DEATH 2024-04-16 10:11:02.972      NaN  551.023689
# 93   13  PLAYER:DEATH 2024-04-16 10:11:09.906      NaN  457.257215
# 28   14  PLAYER:DEATH 2024-04-16 10:11:14.072      NaN  716.714045
# 59   15  PLAYER:DEATH 2024-04-16 10:11:15.455      NaN  432.000000
# 12   16  PLAYER:DEATH 2024-04-16 10:11:18.189      NaN  320.619288
# 27   17     LEVEL:END 2024-04-16 10:11:28.705      3.0         NaN
# 94   18   LEVEL:START 2024-04-16 10:11:28.732      4.0         NaN
# 113  19  PLAYER:DEATH 2024-04-16 10:11:37.256      NaN  434.323533
# 65   20  PLAYER:DEATH 2024-04-16 10:11:40.039      NaN  318.927117
# 47   21  PLAYER:DEATH 2024-04-16 10:11:43.089      NaN  199.406085
# 30   22  PLAYER:DEATH 2024-04-16 10:11:44.139      NaN  432.000000
# 15   23  PLAYER:DEATH 2024-04-16 10:11:46.439      NaN  425.333333
# 128  24  PLAYER:DEATH 2024-04-16 10:11:48.589      NaN  333.952621
# 115  25  PLAYER:DEATH 2024-04-16 10:11:50.622      NaN  353.715729
# 98   26  PLAYER:DEATH 2024-04-16 10:12:04.474      NaN  200.522164
# 85   27  PLAYER:DEATH 2024-04-16 10:12:05.539      NaN  428.666667
# 49   28  PLAYER:DEATH 2024-04-16 10:12:07.856      NaN  428.666667
# 31   29  PLAYER:DEATH 2024-04-16 10:12:13.140      NaN  303.785113
# 52   30  PLAYER:DEATH 2024-04-16 10:12:17.757      NaN  480.521164
# 34   31  PLAYER:DEATH 2024-04-16 10:12:21.407      NaN  467.732000
# 19   32  PLAYER:DEATH 2024-04-16 10:12:22.208      NaN  467.732000
# 3    33     LEVEL:END 2024-04-16 10:12:23.724      4.0         NaN
# 131  34      GAME:END 2024-04-16 10:12:26.174      NaN         NaN
#
#               y result
# 62          NaN    NaN
# 78          NaN    NaN
# 120  630.404401    NaN
# 40   444.719946    NaN
# 26          NaN   PASS
# 11          NaN    NaN
# 90   528.047379    NaN
# 122  441.686500    NaN
# 108  527.258091    NaN
# 91          NaN   PASS
# 112         NaN    NaN
# 124  528.856181    NaN
# 80   532.357023    NaN
# 93   413.835859    NaN
# 28   438.047379    NaN
# 59   400.000000    NaN
# 12   335.285955    NaN
# 27          NaN   PASS
# 94          NaN    NaN
# 113  345.993586    NaN
# 65   331.820667    NaN
# 47   347.406085    NaN
# 30   400.000000    NaN
# 15   496.666667    NaN
# 128  438.047379    NaN
# 115  435.049062    NaN
# 98   334.839871    NaN
# 85   400.000000    NaN
# 49   526.666667    NaN
# 31   531.785113    NaN
# 52   639.468735    NaN
# 34   554.442670    NaN
# 19   554.442670    NaN
# 3           NaN   FAIL
# 131         NaN   FAIL
# id           25
# eventType    25
# timestamp    25
# levelId       0
# x            25
# y            25
# result        0
# dtype: int64

# %% [markdown]
# ## ¿El jugador entiende las tres barras superiores?
#
# + Promedio de vida curada con el máximo de salud por nivel.
#   + Curación jugador.
#   + Cantidad de vida.
# + Promedio de veces que se intenta lanzar una habilidad sin maná por nivel.
#   + Mana insuficiente.
# + Promedio de maná útil que se recoge por nivel.
#   + Recoger maná.

# %% [markdown]
# ## ¿El jugador entiende qué tiene que hacer para salir del nivel, y cuándo lo puede hacer?
# + Promedio de tiempo que tarda desde que puede salir del nivel hasta que sale.
#   + Se puede salir del nivel.
#   + Salir del nivel.
# + Promedio de veces que se intenta salir del nivel sin poder por nivel.
#   + Se intenta salir del nivel.

# %% [markdown]
# ## ¿Entiende el jugador cómo gestionar sus cartas?
# + Promedio de veces que se cambia de cartas entre mazo y mano por sesión de juego.
#     + Mover una carta del mazo a la mano.
# + Promedio de veces que se cambia de cartas entre mano y mazo por sesión de juego.
#     + Mover una carta de la mano al mazo.
# + Promedio de cambios de baraja final por sesión de juego.
#     + Baraja actual (muestra la baraja en un momento dado, permite la posterior comparación entre barajas).
